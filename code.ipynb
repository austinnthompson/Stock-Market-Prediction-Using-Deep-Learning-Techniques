# %% [markdown]
# # Project: Stock Market Prediction Using Deep Learning Techniques

# %% [markdown]
# # Load Python Packages Establish Random Seed, and Set Up CUDA Device

# %%
# Required Libraries and Packages
import matplotlib.pyplot as plt
import sklearn as skl
import numpy as np

import torch
import torchinfo
import torch.nn as nn
import torch.optim as optim

from torch.utils.data import DataLoader, TensorDataset

from transformers import AutoModelForSequenceClassification, AutoTokenizer

from datetime import timedelta
import time

import yfinance as yf
import finnhub

# === PUT YOUR KEY API Key HERE ===
import api_keys
finnhub_api_key = api_keys.get_finnhub_api_key() #<-- ENTER YOUR FINNHUB API KEY HERE

# Establish Seed for reproduceablity
seed = 42
torch.manual_seed(seed)

# Select Device for Computation (NVIDIA GPU or CPU)
if torch.cuda.is_available():
    device = 'cuda'
else:
    device = 'cpu'
print(f'Selected Device: {device}')
# Out:
# Selected Device: cuda

# %% [markdown]
# # Data Collection and Processing

# %% [markdown]
# ## Download SPY ETF Weekly Data (Friday Closes Only, for 10-years):
#
# Using yFinance API.  More about API here: https://ranaroussi.github.io/yfinance/

# %%
ticker = 'SPY'
news_query = 'SPY OR "S&P 500" OR "Standard and Poors 500"'
spy = yf.Ticker(ticker)
df = spy.history(period='10y', interval='1d')
df = df[df.index.dayofweek == 4] #Keep Only Fridays
df = df[['Close', 'Volume']].copy()

test_close = df.iloc[-1, 0]

# drop last row for testing (suppress line below if want to predict next week's return)
df = df[:-1] # Going back one additional week to see model performance against actual stock market returns.

df.tail()
# Out:
#                                 Close     Volume
# Date
# 2025-10-31 00:00:00-04:00  682.059998   87164100
# 2025-11-07 00:00:00-05:00  670.969971  100592400
# 2025-11-14 00:00:00-05:00  671.929993   96846700
# 2025-11-21 00:00:00-05:00  659.030029  123956200
# 2025-11-28 00:00:00-05:00  683.390015   49212000

# %% [markdown]
# ## Build Technical Features from SPY Weekly Information:
#
# 1) **Rolling Averages**
# 2) **Momentum**
# 3) **Volume**
# 4) **Relative Strength Index (RSI)**
# 5) **Moving Average Convergence Divergence (MACD)**
#
# More about this can be found in articles at https://www.investopedia.com/.

# %%
def add_technical_features(df):
    df = df.copy()
    close = df['Close']
    volume = df['Volume']

    # Rolling statistics
    for weeks in [1, 2, 4]:
        df[f'close_ma_{weeks}w'] = close.rolling(window=weeks).mean()
        df[f'close_std_{weeks}w'] = close.rolling(window=weeks).std()
        df[f'volume_ma_{weeks}w'] = volume.rolling(window=weeks).mean()

    # Momentum (return over past N weeks)
    for weeks in [1, 2, 4]:
        df[f'momentum_{weeks}w'] = close.pct_change(periods=weeks)

    # --- RSI (weekly RSI) ---
    def weekly_rsi(series, period=14):
        delta = series.diff()
        gain = delta.where(delta > 0, 0)
        loss = -delta.where(delta < 0, 0)

        avg_gain = gain.rolling(period).mean()
        avg_loss = loss.rolling(period).mean()

        rs = avg_gain / avg_loss
        rsi = 100 - (100 / (1 + rs))
        return rsi

    # Weekly RSI for 1, 2, 4 "cycles"
    for w in [1, 2, 4]:
        period = w * 14 // 1   # 14-week RSI scaled (optional)
        df[f'rsi_{w}w'] = weekly_rsi(close, period=max(2, period))

    # --- MACD (weekly MACD) ---
    # Use weekly EMAs instead of daily 12/26-day EMAs
    df['macd'] = close.ewm(span=12, adjust=False).mean() - close.ewm(span=26, adjust=False).mean()
    df['macd_signal'] = df['macd'].ewm(span=9, adjust=False).mean()
    df['macd_hist'] = df['macd'] - df['macd_signal']

    # Establish Target Variable: Next Week's Return
    df['target'] = np.log(df['Close'].shift(-1) / df['Close'])

    df = df.drop('close_std_1w', axis=1) # Droping NaN heavy column.

    # Keep the last row even if it has NaN in 'target'
    df = df.dropna(subset=df.columns.difference(['target'])).copy()

    return df

df = add_technical_features(df)

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
price_cols = df.drop('target', axis=1).columns
df[price_cols] = scaler.fit_transform(df[price_cols])              

print(f'number of features: {df.shape[1]-1}') #exclude target
df.tail()
# Out:
# number of features: 19
#                               Close    Volume  close_ma_1w  volume_ma_1w  \
# Date
# 2025-10-31 00:00:00-04:00  2.411320 -0.033038     2.411320     -0.033038
# 2025-11-07 00:00:00-05:00  2.324710  0.286670     2.324710      0.286670
# 2025-11-14 00:00:00-05:00  2.332207  0.197490     2.332207      0.197490
# 2025-11-21 00:00:00-05:00  2.231462  0.842927     2.231462      0.842927
# 2025-11-28 00:00:00-05:00  2.421707 -0.936621     2.421707     -0.936621
#
#                            close_ma_2w  close_std_2w  volume_ma_2w  \
# Date
# 2025-10-31 00:00:00-04:00     2.403671     -0.264525     -0.215328
# 2025-11-07 00:00:00-05:00     2.379078      0.700744      0.146507
# 2025-11-14 00:00:00-05:00     2.339407     -0.856283      0.280045
# 2025-11-21 00:00:00-05:00     2.292649      0.978940      0.602269
# 2025-11-28 00:00:00-05:00     2.337528      2.740397     -0.054689
#
#                            close_ma_4w  close_std_4w  volume_ma_4w  \
# Date
# 2025-10-31 00:00:00-04:00     2.341000      1.379298      0.495567
# 2025-11-07 00:00:00-05:00     2.376315      0.227850      0.035380
# 2025-11-14 00:00:00-05:00     2.391150     -0.308537      0.038085
# 2025-11-21 00:00:00-05:00     2.355303      0.599272      0.426069
# 2025-11-28 00:00:00-05:00     2.357920      0.711433      0.129196
#
#                            momentum_1w  momentum_2w  momentum_4w    rsi_1w  \
# Date
# 2025-10-31 00:00:00-04:00     0.158395     0.613511     0.152095  0.507555
# 2025-11-07 00:00:00-05:00    -0.764861    -0.457225     0.330447  0.683250
# 2025-11-14 00:00:00-05:00    -0.065739    -0.623774    -0.016940  0.421465
# 2025-11-21 00:00:00-05:00    -0.881001    -0.711626    -0.840300 -0.263731
# 2025-11-28 00:00:00-05:00     1.338502     0.328714    -0.219246  0.219324
#
#                              rsi_2w    rsi_4w      macd  macd_signal  \
# Date
# 2025-10-31 00:00:00-04:00  1.919416  0.114594  1.993368     1.916200
# 2025-11-07 00:00:00-05:00  1.422247 -0.057000  1.916369     1.952246
# 2025-11-14 00:00:00-05:00  1.283644 -0.061653  1.833940     1.963228
# 2025-11-21 00:00:00-05:00  0.774072 -0.280832  1.611748     1.923884
# 2025-11-28 00:00:00-05:00  1.089491 -0.111080  1.649405     1.900566
#
#                            macd_hist    target
# Date
# 2025-10-31 00:00:00-04:00   0.718943 -0.016393
# 2025-11-07 00:00:00-05:00   0.365173  0.001430
# 2025-11-14 00:00:00-05:00   0.068224 -0.019385
# 2025-11-21 00:00:00-05:00  -0.528014  0.036297
# 2025-11-28 00:00:00-05:00  -0.338147       NaN

# %% [markdown]
# ## Download and Process News Information:

# %% [markdown]
# ### Load Pre-Trained FinBERT-Tone Model:
#
# **Brief Description:** "FinBERT is a BERT model pre-trained on financial communication text. The purpose is to enhance financial NLP research and practice. It is trained on the following three financial communication corpus. The total corpora size is 4.9B tokens.
#
#     - Corporate Reports 10-K & 10-Q: 2.5B tokens
#     - Earnings Call Transcripts: 1.3B tokens
#     - Analyst Reports: 1.1B tokens"
#
# **Hugging Face Documentation:** https://huggingface.co/yiyanghkust/finbert-tone

# %%
# Establish Model:
checkpoint = 'yiyanghkust/finbert-tone'

# %%
# Download Model:
model = AutoModelForSequenceClassification.from_pretrained(
    checkpoint, 
    local_files_only=False,   # Can set this to True after you've downloaded the model once
    output_hidden_states = True
).to(device)

print(f'Loaded Model: {checkpoint}. Model info below.')

torchinfo.summary(model)
# Out:
# Loaded Model: yiyanghkust/finbert-tone. Model info below.
# =====================================================================================
# Layer (type:depth-idx)                                       Param #
# =====================================================================================
# BertForSequenceClassification                                --
# ├─BertModel: 1-1                                             --
# │    └─BertEmbeddings: 2-1                                   --
# │    │    └─Embedding: 3-1                                   23,710,464
# │    │    └─Embedding: 3-2                                   393,216
# │    │    └─Embedding: 3-3                                   1,536
# │    │    └─LayerNorm: 3-4                                   1,536
# │    │    └─Dropout: 3-5                                     --
# │    └─BertEncoder: 2-2                                      --
# │    │    └─ModuleList: 3-6                                  85,054,464
# │    └─BertPooler: 2-3                                       --
# │    │    └─Linear: 3-7                                      590,592
# │    │    └─Tanh: 3-8                                        --
# ├─Dropout: 1-2                                               --
# ├─Linear: 1-3                                                2,307
# =====================================================================================
# Total params: 109,754,115
# Trainable params: 109,754,115
# Non-trainable params: 0
# =====================================================================================

# %%
# Download Tokenizer:
tokenizer = AutoTokenizer.from_pretrained(
    checkpoint,
    local_files_only=False # Can set this to True after you've downloaded the tokenizer once
)

print(f'Loaded Tokenizer: {checkpoint}')
# Out:
# Loaded Tokenizer: yiyanghkust/finbert-tone

# %% [markdown]
# ### Collect News for Each Friday using Finnhub API and Create Weekly Embedings using FinBERT:
#
# More about Finnhub: https://finnhub.io

# %%
## Collect News Data
finnhub_client = finnhub.Client(finnhub_api_key)
NEWS_CATEGORY = 'general'  # Use 'general' for market-wide news

#################### Note ######################################
# Finnhub's free tier will only allow collection of news information up to 1 years back.  Paid plans can get up to 20+ years.

def get_weekly_news_embeddings(date):
    start = (date - timedelta(days=6)).strftime('%Y-%m-%d')
    end =  (date).strftime('%Y-%m-%d')

    try:
        if ticker:
            # Company-specific news
            news = finnhub_client.company_news(ticker, _from=start, to=end)
        else:
            # General market or category news
            news = finnhub_client.general_news(NEWS_CATEGORY, min_id=0)
            # Filter by date range (Finnhub general news doesn't support direct date filter, so we filter manually)
            news = [
                item for item in news
                if start <= item['datetime'][:10] <= end
            ]
        
        # Extract relevant text fields
        texts = []
        for article in news[:100]:  # Limit to avoid overload
            title = article.get('headline', '') or article.get('title', '')
            summary = article.get('summary', '') or article.get('description', '')
            texts.append(f"{title} {summary}".strip())

        full_text = " ".join(texts)

        if not full_text.strip():
            print(f"No news found for {start} to {end}")
            # Return zero embedding if no news
            return torch.zeros(768).to(device)  # Adjust size based on your model (e.g., BERT=768)

        inputs = tokenizer(full_text, return_tensors='pt', padding=True, truncation=True, max_length = 512).to(device)

        with torch.no_grad():
            outputs = model(**inputs)
            hidden_states = outputs.hidden_states
            last_hidden_state = hidden_states[-1]
        embedding = last_hidden_state.mean(dim=1).squeeze()
        return embedding

    except Exception as e:
        print(f"Error fetching news for {start} to {end}: {e}")
        return torch.zeros(768).to(device)  # Adjust size based on your model (e.g., BERT=768)

news_embeddings = []
for date in df.index:
    embedding = get_weekly_news_embeddings(date)
    news_embeddings.append(embedding)
    time.sleep(1)  # To respect API rate limits (60 API calls per minute with free tier)
news_embeddings = torch.stack(news_embeddings).to(device)

print(f"Collected {len(news_embeddings)} news embeddings | Shape: {news_embeddings.shape}")
# Out:
# No news found for 2017-01-14 to 2017-01-20
# No news found for 2017-01-21 to 2017-01-27
# No news found for 2017-01-28 to 2017-02-03
# No news found for 2017-02-04 to 2017-02-10
# No news found for 2017-02-11 to 2017-02-17
# No news found for 2017-02-18 to 2017-02-24
# No news found for 2017-02-25 to 2017-03-03
# No news found for 2017-03-04 to 2017-03-10
# No news found for 2017-03-10 to 2017-03-17
# No news found for 2017-03-18 to 2017-03-24
# No news found for 2017-03-25 to 2017-03-31
# No news found for 2017-04-01 to 2017-04-07
# No news found for 2017-04-15 to 2017-04-21
# No news found for 2017-04-22 to 2017-04-28
# No news found for 2017-04-29 to 2017-05-05
# No news found for 2017-05-06 to 2017-05-12
# No news found for 2017-05-13 to 2017-05-19
# No news found for 2017-05-20 to 2017-05-26
# No news found for 2017-05-27 to 2017-06-02
# No news found for 2017-06-03 to 2017-06-09
# No news found for 2017-06-10 to 2017-06-16
# No news found for 2017-06-17 to 2017-06-23
# No news found for 2017-06-24 to 2017-06-30
# No news found for 2017-07-01 to 2017-07-07
# No news found for 2017-07-08 to 2017-07-14
# No news found for 2017-07-15 to 2017-07-21
# No news found for 2017-07-22 to 2017-07-28
# No news found for 2017-07-29 to 2017-08-04
# No news found for 2017-08-05 to 2017-08-11
# No news found for 2017-08-12 to 2017-08-18
# No news found for 2017-08-19 to 2017-08-25
# No news found for 2017-08-26 to 2017-09-01
# No news found for 2017-09-02 to 2017-09-08
# No news found for 2017-09-09 to 2017-09-15
# No news found for 2017-09-16 to 2017-09-22
# No news found for 2017-09-23 to 2017-09-29
# No news found for 2017-09-30 to 2017-10-06
# No news found for 2017-10-07 to 2017-10-13
# No news found for 2017-10-14 to 2017-10-20
# No news found for 2017-10-21 to 2017-10-27
# No news found for 2017-10-28 to 2017-11-03
# No news found for 2017-11-04 to 2017-11-10
# No news found for 2017-11-11 to 2017-11-17
# No news found for 2017-11-18 to 2017-11-24
# No news found for 2017-11-25 to 2017-12-01
# No news found for 2017-12-02 to 2017-12-08
# No news found for 2017-12-09 to 2017-12-15
# No news found for 2017-12-16 to 2017-12-22
# No news found for 2017-12-23 to 2017-12-29
# No news found for 2017-12-30 to 2018-01-05
# No news found for 2018-01-06 to 2018-01-12
# No news found for 2018-01-13 to 2018-01-19
# No news found for 2018-01-20 to 2018-01-26
# No news found for 2018-01-27 to 2018-02-02
# No news found for 2018-02-03 to 2018-02-09
# No news found for 2018-02-10 to 2018-02-16
# No news found for 2018-02-17 to 2018-02-23
# No news found for 2018-02-24 to 2018-03-02
# No news found for 2018-03-03 to 2018-03-09
# No news found for 2018-03-09 to 2018-03-16
# No news found for 2018-03-17 to 2018-03-23
# No news found for 2018-03-31 to 2018-04-06
# No news found for 2018-04-07 to 2018-04-13
# No news found for 2018-04-14 to 2018-04-20
# No news found for 2018-04-21 to 2018-04-27
# No news found for 2018-04-28 to 2018-05-04
# No news found for 2018-05-05 to 2018-05-11
# No news found for 2018-05-12 to 2018-05-18
# No news found for 2018-05-19 to 2018-05-25
# No news found for 2018-05-26 to 2018-06-01
# No news found for 2018-06-02 to 2018-06-08
# No news found for 2018-06-09 to 2018-06-15
# No news found for 2018-06-16 to 2018-06-22
# No news found for 2018-06-23 to 2018-06-29
# No news found for 2018-06-30 to 2018-07-06
# No news found for 2018-07-07 to 2018-07-13
# No news found for 2018-07-14 to 2018-07-20
# No news found for 2018-07-21 to 2018-07-27
# No news found for 2018-07-28 to 2018-08-03
# No news found for 2018-08-04 to 2018-08-10
# No news found for 2018-08-11 to 2018-08-17
# No news found for 2018-08-18 to 2018-08-24
# No news found for 2018-08-25 to 2018-08-31
# No news found for 2018-09-01 to 2018-09-07
# No news found for 2018-09-08 to 2018-09-14
# No news found for 2018-09-15 to 2018-09-21
# No news found for 2018-09-22 to 2018-09-28
# No news found for 2018-09-29 to 2018-10-05
# No news found for 2018-10-06 to 2018-10-12
# No news found for 2018-10-13 to 2018-10-19
# No news found for 2018-10-20 to 2018-10-26
# No news found for 2018-10-27 to 2018-11-02
# No news found for 2018-11-03 to 2018-11-09
# No news found for 2018-11-10 to 2018-11-16
# No news found for 2018-11-17 to 2018-11-23
# No news found for 2018-11-24 to 2018-11-30
# No news found for 2018-12-01 to 2018-12-07
# No news found for 2018-12-08 to 2018-12-14
# No news found for 2018-12-15 to 2018-12-21
# No news found for 2018-12-22 to 2018-12-28
# No news found for 2018-12-29 to 2019-01-04
# No news found for 2019-01-05 to 2019-01-11
# No news found for 2019-01-12 to 2019-01-18
# No news found for 2019-01-19 to 2019-01-25
# No news found for 2019-01-26 to 2019-02-01
# No news found for 2019-02-02 to 2019-02-08
# No news found for 2019-02-09 to 2019-02-15
# No news found for 2019-02-16 to 2019-02-22
# No news found for 2019-02-23 to 2019-03-01
# No news found for 2019-03-02 to 2019-03-08
# No news found for 2019-03-08 to 2019-03-15
# No news found for 2019-03-16 to 2019-03-22
# No news found for 2019-03-23 to 2019-03-29
# No news found for 2019-03-30 to 2019-04-05
# No news found for 2019-04-06 to 2019-04-12
# No news found for 2019-04-20 to 2019-04-26
# No news found for 2019-04-27 to 2019-05-03
# No news found for 2019-05-04 to 2019-05-10
# No news found for 2019-05-11 to 2019-05-17
# No news found for 2019-05-18 to 2019-05-24
# No news found for 2019-05-25 to 2019-05-31
# No news found for 2019-06-01 to 2019-06-07
# No news found for 2019-06-08 to 2019-06-14
# No news found for 2019-06-15 to 2019-06-21
# No news found for 2019-06-22 to 2019-06-28
# No news found for 2019-06-29 to 2019-07-05
# No news found for 2019-07-06 to 2019-07-12
# No news found for 2019-07-13 to 2019-07-19
# No news found for 2019-07-20 to 2019-07-26
# No news found for 2019-07-27 to 2019-08-02
# No news found for 2019-08-03 to 2019-08-09
# No news found for 2019-08-10 to 2019-08-16
# No news found for 2019-08-17 to 2019-08-23
# No news found for 2019-08-24 to 2019-08-30
# No news found for 2019-08-31 to 2019-09-06
# No news found for 2019-09-07 to 2019-09-13
# No news found for 2019-09-14 to 2019-09-20
# No news found for 2019-09-21 to 2019-09-27
# No news found for 2019-09-28 to 2019-10-04
# No news found for 2019-10-05 to 2019-10-11
# No news found for 2019-10-12 to 2019-10-18
# No news found for 2019-10-19 to 2019-10-25
# No news found for 2019-10-26 to 2019-11-01
# No news found for 2019-11-02 to 2019-11-08
# No news found for 2019-11-09 to 2019-11-15
# No news found for 2019-11-16 to 2019-11-22
# No news found for 2019-11-23 to 2019-11-29
# No news found for 2019-11-30 to 2019-12-06
# No news found for 2019-12-07 to 2019-12-13
# No news found for 2019-12-14 to 2019-12-20
# No news found for 2019-12-21 to 2019-12-27
# No news found for 2019-12-28 to 2020-01-03
# No news found for 2020-01-04 to 2020-01-10
# No news found for 2020-01-11 to 2020-01-17
# No news found for 2020-01-18 to 2020-01-24
# No news found for 2020-01-25 to 2020-01-31
# No news found for 2020-02-01 to 2020-02-07
# No news found for 2020-02-08 to 2020-02-14
# No news found for 2020-02-15 to 2020-02-21
# No news found for 2020-02-22 to 2020-02-28
# No news found for 2020-02-29 to 2020-03-06
# No news found for 2020-03-06 to 2020-03-13
# No news found for 2020-03-14 to 2020-03-20
# No news found for 2020-03-21 to 2020-03-27
# No news found for 2020-03-28 to 2020-04-03
# No news found for 2020-04-11 to 2020-04-17
# No news found for 2020-04-18 to 2020-04-24
# No news found for 2020-04-25 to 2020-05-01
# No news found for 2020-05-02 to 2020-05-08
# No news found for 2020-05-09 to 2020-05-15
# No news found for 2020-05-16 to 2020-05-22
# No news found for 2020-05-23 to 2020-05-29
# No news found for 2020-05-30 to 2020-06-05
# No news found for 2020-06-06 to 2020-06-12
# No news found for 2020-06-13 to 2020-06-19
# No news found for 2020-06-20 to 2020-06-26
# No news found for 2020-07-04 to 2020-07-10
# No news found for 2020-07-11 to 2020-07-17
# No news found for 2020-07-18 to 2020-07-24
# No news found for 2020-07-25 to 2020-07-31
# No news found for 2020-08-01 to 2020-08-07
# No news found for 2020-08-08 to 2020-08-14
# No news found for 2020-08-15 to 2020-08-21
# No news found for 2020-08-22 to 2020-08-28
# No news found for 2020-08-29 to 2020-09-04
# No news found for 2020-09-05 to 2020-09-11
# No news found for 2020-09-12 to 2020-09-18
# No news found for 2020-09-19 to 2020-09-25
# No news found for 2020-09-26 to 2020-10-02
# No news found for 2020-10-03 to 2020-10-09
# No news found for 2020-10-10 to 2020-10-16
# No news found for 2020-10-17 to 2020-10-23
# No news found for 2020-10-24 to 2020-10-30
# No news found for 2020-10-31 to 2020-11-06
# No news found for 2020-11-07 to 2020-11-13
# No news found for 2020-11-14 to 2020-11-20
# No news found for 2020-11-21 to 2020-11-27
# No news found for 2020-11-28 to 2020-12-04
# No news found for 2020-12-05 to 2020-12-11
# No news found for 2020-12-12 to 2020-12-18
# No news found for 2021-01-02 to 2021-01-08
# No news found for 2021-01-09 to 2021-01-15
# No news found for 2021-01-16 to 2021-01-22
# No news found for 2021-01-23 to 2021-01-29
# No news found for 2021-01-30 to 2021-02-05
# No news found for 2021-02-06 to 2021-02-12
# No news found for 2021-02-13 to 2021-02-19
# No news found for 2021-02-20 to 2021-02-26
# No news found for 2021-02-27 to 2021-03-05
# No news found for 2021-03-06 to 2021-03-12
# No news found for 2021-03-12 to 2021-03-19
# No news found for 2021-03-20 to 2021-03-26
# No news found for 2021-04-03 to 2021-04-09
# No news found for 2021-04-10 to 2021-04-16
# No news found for 2021-04-17 to 2021-04-23
# No news found for 2021-04-24 to 2021-04-30
# No news found for 2021-05-01 to 2021-05-07
# No news found for 2021-05-08 to 2021-05-14
# No news found for 2021-05-15 to 2021-05-21
# No news found for 2021-05-22 to 2021-05-28
# No news found for 2021-05-29 to 2021-06-04
# No news found for 2021-06-05 to 2021-06-11
# No news found for 2021-06-12 to 2021-06-18
# No news found for 2021-06-19 to 2021-06-25
# No news found for 2021-06-26 to 2021-07-02
# No news found for 2021-07-03 to 2021-07-09
# No news found for 2021-07-10 to 2021-07-16
# No news found for 2021-07-17 to 2021-07-23
# No news found for 2021-07-24 to 2021-07-30
# No news found for 2021-07-31 to 2021-08-06
# No news found for 2021-08-07 to 2021-08-13
# No news found for 2021-08-14 to 2021-08-20
# No news found for 2021-08-21 to 2021-08-27
# No news found for 2021-08-28 to 2021-09-03
# No news found for 2021-09-04 to 2021-09-10
# No news found for 2021-09-11 to 2021-09-17
# No news found for 2021-09-18 to 2021-09-24
# No news found for 2021-09-25 to 2021-10-01
# No news found for 2021-10-02 to 2021-10-08
# No news found for 2021-10-09 to 2021-10-15
# No news found for 2021-10-16 to 2021-10-22
# No news found for 2021-10-23 to 2021-10-29
# No news found for 2021-10-30 to 2021-11-05
# No news found for 2021-11-06 to 2021-11-12
# No news found for 2021-11-13 to 2021-11-19
# No news found for 2021-11-20 to 2021-11-26
# No news found for 2021-11-27 to 2021-12-03
# No news found for 2021-12-04 to 2021-12-10
# No news found for 2021-12-11 to 2021-12-17
# No news found for 2021-12-25 to 2021-12-31
# No news found for 2022-01-01 to 2022-01-07
# No news found for 2022-01-08 to 2022-01-14
# No news found for 2022-01-15 to 2022-01-21
# No news found for 2022-01-22 to 2022-01-28
# No news found for 2022-01-29 to 2022-02-04
# No news found for 2022-02-05 to 2022-02-11
# No news found for 2022-02-12 to 2022-02-18
# No news found for 2022-02-19 to 2022-02-25
# No news found for 2022-02-26 to 2022-03-04
# No news found for 2022-03-05 to 2022-03-11
# No news found for 2022-03-11 to 2022-03-18
# No news found for 2022-03-19 to 2022-03-25
# No news found for 2022-03-26 to 2022-04-01
# No news found for 2022-04-02 to 2022-04-08
# No news found for 2022-04-16 to 2022-04-22
# No news found for 2022-04-23 to 2022-04-29
# No news found for 2022-04-30 to 2022-05-06
# No news found for 2022-05-07 to 2022-05-13
# No news found for 2022-05-14 to 2022-05-20
# No news found for 2022-05-21 to 2022-05-27
# No news found for 2022-05-28 to 2022-06-03
# No news found for 2022-06-04 to 2022-06-10
# No news found for 2022-06-11 to 2022-06-17
# No news found for 2022-06-18 to 2022-06-24
# No news found for 2022-06-25 to 2022-07-01
# No news found for 2022-07-02 to 2022-07-08
# No news found for 2022-07-09 to 2022-07-15
# No news found for 2022-07-16 to 2022-07-22
# No news found for 2022-07-23 to 2022-07-29
# No news found for 2022-07-30 to 2022-08-05
# No news found for 2022-08-06 to 2022-08-12
# No news found for 2022-08-13 to 2022-08-19
# No news found for 2022-08-20 to 2022-08-26
# No news found for 2022-08-27 to 2022-09-02
# No news found for 2022-09-03 to 2022-09-09
# No news found for 2022-09-10 to 2022-09-16
# No news found for 2022-09-17 to 2022-09-23
# No news found for 2022-09-24 to 2022-09-30
# No news found for 2022-10-01 to 2022-10-07
# No news found for 2022-10-08 to 2022-10-14
# No news found for 2022-10-15 to 2022-10-21
# No news found for 2022-10-22 to 2022-10-28
# No news found for 2022-10-29 to 2022-11-04
# No news found for 2022-11-05 to 2022-11-11
# No news found for 2022-11-12 to 2022-11-18
# No news found for 2022-11-19 to 2022-11-25
# No news found for 2022-11-26 to 2022-12-02
# No news found for 2022-12-03 to 2022-12-09
# No news found for 2022-12-10 to 2022-12-16
# No news found for 2022-12-17 to 2022-12-23
# No news found for 2022-12-24 to 2022-12-30
# No news found for 2022-12-31 to 2023-01-06
# No news found for 2023-01-07 to 2023-01-13
# No news found for 2023-01-14 to 2023-01-20
# No news found for 2023-01-21 to 2023-01-27
# No news found for 2023-01-28 to 2023-02-03
# No news found for 2023-02-04 to 2023-02-10
# No news found for 2023-02-11 to 2023-02-17
# No news found for 2023-02-18 to 2023-02-24
# No news found for 2023-02-25 to 2023-03-03
# No news found for 2023-03-04 to 2023-03-10
# No news found for 2023-03-10 to 2023-03-17
# No news found for 2023-03-18 to 2023-03-24
# No news found for 2023-03-25 to 2023-03-31
# No news found for 2023-04-08 to 2023-04-14
# No news found for 2023-04-15 to 2023-04-21
# No news found for 2023-04-22 to 2023-04-28
# No news found for 2023-04-29 to 2023-05-05
# No news found for 2023-05-06 to 2023-05-12
# No news found for 2023-05-13 to 2023-05-19
# No news found for 2023-05-20 to 2023-05-26
# No news found for 2023-05-27 to 2023-06-02
# No news found for 2023-06-03 to 2023-06-09
# No news found for 2023-06-10 to 2023-06-16
# No news found for 2023-06-17 to 2023-06-23
# No news found for 2023-06-24 to 2023-06-30
# No news found for 2023-07-01 to 2023-07-07
# No news found for 2023-07-08 to 2023-07-14
# No news found for 2023-07-15 to 2023-07-21
# No news found for 2023-07-22 to 2023-07-28
# No news found for 2023-07-29 to 2023-08-04
# No news found for 2023-08-05 to 2023-08-11
# No news found for 2023-08-12 to 2023-08-18
# No news found for 2023-08-19 to 2023-08-25
# No news found for 2023-08-26 to 2023-09-01
# No news found for 2023-09-02 to 2023-09-08
# No news found for 2023-09-09 to 2023-09-15
# No news found for 2023-09-16 to 2023-09-22
# No news found for 2023-09-23 to 2023-09-29
# No news found for 2023-09-30 to 2023-10-06
# No news found for 2023-10-07 to 2023-10-13
# No news found for 2023-10-14 to 2023-10-20
# No news found for 2023-10-21 to 2023-10-27
# No news found for 2023-10-28 to 2023-11-03
# No news found for 2023-11-04 to 2023-11-10
# No news found for 2023-11-11 to 2023-11-17
# No news found for 2023-11-18 to 2023-11-24
# No news found for 2023-11-25 to 2023-12-01
# No news found for 2023-12-02 to 2023-12-08
# No news found for 2023-12-09 to 2023-12-15
# No news found for 2023-12-16 to 2023-12-22
# No news found for 2023-12-23 to 2023-12-29
# No news found for 2023-12-30 to 2024-01-05
# No news found for 2024-01-06 to 2024-01-12
# No news found for 2024-01-13 to 2024-01-19
# No news found for 2024-01-20 to 2024-01-26
# No news found for 2024-01-27 to 2024-02-02
# No news found for 2024-02-03 to 2024-02-09
# No news found for 2024-02-10 to 2024-02-16
# No news found for 2024-02-17 to 2024-02-23
# No news found for 2024-02-24 to 2024-03-01
# No news found for 2024-03-02 to 2024-03-08
# No news found for 2024-03-08 to 2024-03-15
# No news found for 2024-03-16 to 2024-03-22
# No news found for 2024-03-30 to 2024-04-05
# No news found for 2024-04-06 to 2024-04-12
# No news found for 2024-04-13 to 2024-04-19
# No news found for 2024-04-20 to 2024-04-26
# No news found for 2024-04-27 to 2024-05-03
# No news found for 2024-05-04 to 2024-05-10
# No news found for 2024-05-11 to 2024-05-17
# No news found for 2024-05-18 to 2024-05-24
# No news found for 2024-05-25 to 2024-05-31
# No news found for 2024-06-01 to 2024-06-07
# No news found for 2024-06-08 to 2024-06-14
# No news found for 2024-06-15 to 2024-06-21
# No news found for 2024-06-22 to 2024-06-28
# No news found for 2024-06-29 to 2024-07-05
# No news found for 2024-07-06 to 2024-07-12
# No news found for 2024-07-13 to 2024-07-19
# No news found for 2024-07-20 to 2024-07-26
# No news found for 2024-07-27 to 2024-08-02
# No news found for 2024-08-03 to 2024-08-09
# No news found for 2024-08-10 to 2024-08-16
# No news found for 2024-08-17 to 2024-08-23
# No news found for 2024-08-24 to 2024-08-30
# No news found for 2024-08-31 to 2024-09-06
# No news found for 2024-09-07 to 2024-09-13
# No news found for 2024-09-14 to 2024-09-20
# No news found for 2024-09-21 to 2024-09-27
# No news found for 2024-09-28 to 2024-10-04
# No news found for 2024-10-05 to 2024-10-11
# No news found for 2024-10-12 to 2024-10-18
# No news found for 2024-10-19 to 2024-10-25
# No news found for 2024-10-26 to 2024-11-01
# No news found for 2024-11-02 to 2024-11-08
# No news found for 2024-11-09 to 2024-11-15
# No news found for 2024-11-16 to 2024-11-22
# No news found for 2024-11-23 to 2024-11-29
# No news found for 2024-11-30 to 2024-12-06
# No news found for 2024-12-07 to 2024-12-13
# Collected 449 news embeddings | Shape: torch.Size([449, 768])

# %% [markdown]
# # Establish Training and Test Sets and Establish Data Loaders

# %% [markdown]
# ## Define X's and Y's

# %%
sequence_length = 4  ### Important for GRU style RNN

def create_sequences(df, news_embeddings, seq_length=sequence_length):
    X_price = []
    X_news = []
    y = []
    
    price_features = df.drop('target', axis=1).values   # (N, 19)
    targets        = df['target'].values                # (N,)
    
    for i in range(seq_length, len(df)-1):
        X_price.append(price_features[i-seq_length:i])   # (12, 19)
        X_news.append(news_embeddings[i-seq_length:i])   # (12, 768)
        y.append(targets[i])
    
    return (np.stack(X_price),           # (samples, 12, 19)
            np.stack(X_news),            # (samples, 12, 768)
            np.array(y))                 # (samples,)

# Apply after you have df and news_embeddings
X_price_seq, X_news_seq, y_seq = create_sequences(df, news_embeddings.cpu().numpy(), seq_length=sequence_length)
print(X_price_seq.shape, X_news_seq.shape, y_seq.shape)
# Out:
# (444, 4, 19) (444, 4, 768) (444,)

# %% [markdown]
# ## Establish Training/Test Sets and Data Loader

# %%
# Split into Train and Test Sets
X_news_train, X_news_test, X_price_train, X_price_test, y_train, y_test = skl.model_selection.train_test_split(
    X_news_seq, X_price_seq, y_seq,
    test_size=0.2,
    random_state=seed,
    shuffle=False   # important for time series!
)

# Convert to torch tensors
X_news_train  = torch.tensor(X_news_train,  dtype=torch.float32)
X_news_test   = torch.tensor(X_news_test,   dtype=torch.float32)
X_price_train = torch.tensor(X_price_train, dtype=torch.float32)
X_price_test  = torch.tensor(X_price_test,  dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_test  = torch.tensor(y_test,  dtype=torch.float32)

# Create DataLoaders
train_dataset = TensorDataset(X_news_train, X_price_train, y_train)
test_dataset  = TensorDataset(X_news_test,  X_price_test,  y_test)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader  = DataLoader(test_dataset,  batch_size=32, shuffle=False)

print(f'Training samples: {len(train_dataset)} and test samples: {len(test_dataset)}')
# Out:
# Training samples: 355 and test samples: 89

# %% [markdown]
# # Define the Model
#
# 1) **1-D CNN**
# 2) **News Embedding Compressor**
# 3) **RNN**

# %%
class SPY_Predictor(nn.Module):
    def __init__(self, price_dim=19, news_dim=768, hidden=128, dropout=0.3):
        super().__init__()
        
        # 1D CNN on price features
        self.cnn = nn.Sequential(
            nn.Conv1d(price_dim, 64, kernel_size=3, padding=1),
            nn.BatchNorm1d(64),
            nn.ReLU(),
            nn.Conv1d(64, 128, kernel_size=3, padding=1),
            nn.BatchNorm1d(128),
            nn.ReLU(),
            nn.Conv1d(128, hidden, kernel_size=3, padding=1),
            nn.AdaptiveMaxPool1d(1)
        )

        # News embedding compressor
        self.news_proj = nn.Linear(news_dim, 64)

        # RNN / GRU
        self.rnn = nn.GRU(hidden + 64, hidden, num_layers=2,
                          batch_first=True, dropout=dropout, bidirectional=True)
        self.fc_mu  = nn.Linear(hidden*2, 1)
        self.dropout = nn.Dropout(dropout)

    def forward(self, price_seq, news_seq):
        # price_seq: (B, 52, price_dim)
        # news_seq:  (B, 52, 768)
        B, T, _ = price_seq.shape
        price_seq = price_seq.permute(0, 2, 1)  # (B, price_dim, 52)
        cnn_out = self.cnn(price_seq).view(B, -1)      # (B, hidden)
        cnn_out = cnn_out.unsqueeze(1).repeat(1, T, 1) # (B, 52, hidden)

        news_compressed = torch.tanh(self.news_proj(news_seq))  # (B, 52, 64)
        combined = torch.cat([cnn_out, news_compressed], dim=-1) # (B, 52, hidden+64)
        combined = self.dropout(combined)
        rnn_out, _ = self.rnn(combined) # (B, 52, hidden*2)
        final = rnn_out[:,-1,:]
        # last timestep
        mu = self.fc_mu(final).squeeze(-1)
        return mu

# %%
model = SPY_Predictor().to(device)

model
# Out:
# SPY_Predictor(
#   (cnn): Sequential(
#     (0): Conv1d(19, 64, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): BatchNorm1d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU()
#     (3): Conv1d(64, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (4): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (5): ReLU()
#     (6): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (7): AdaptiveMaxPool1d(output_size=1)
#   )
#   (news_proj): Linear(in_features=768, out_features=64, bias=True)
#   (rnn): GRU(192, 128, num_layers=2, batch_first=True, dropout=0.3, bidirectional=True)
#   (fc_mu): Linear(in_features=256, out_features=1, bias=True)
#   (dropout): Dropout(p=0.3, inplace=False)
# )

# %% [markdown]
# # Training Loop and Testing Model Performance

# %%
# Train the Model:

optimizer = optim.Adam(model.parameters(), lr=0.000_001)    
criterion = nn.MSELoss()    # Set to MSE Loss for regression

num_epochs = 2000
for epoch in range(num_epochs):
    model.train()       # Set model to "training" mode
    train_loss = 0
    for batch_X_news, batch_X_price, batch_y in train_loader:
        batch_X_news, batch_X_price, batch_y = batch_X_news.to(device), batch_X_price.to(device), batch_y.to(device)   # Send the batch to the device
        optimizer.zero_grad()   # Reset gradient to zero
        # Forward Pass
        batch_y_hat = model(batch_X_price, batch_X_news) # Get current predictions
        loss = criterion(batch_y_hat, batch_y) # Compute loss
        # Backward Pass
        loss.backward()     # Compute (stochastic) gradient
        # Descent Step
        optimizer.step()    # Take gradient step (adjust parameters)
        # Update running total of loss
        train_loss += loss.item()

    if epoch % 100 == 0:
        print(f'Epoch {epoch:4d}: Mean Training Loss = {train_loss / len(train_loader):.5f}')
# Out:
# Epoch    0: Mean Training Loss = 0.01259
# Epoch  100: Mean Training Loss = 0.00261
# Epoch  200: Mean Training Loss = 0.00289
# Epoch  300: Mean Training Loss = 0.00199
# Epoch  400: Mean Training Loss = 0.00170
# Epoch  500: Mean Training Loss = 0.00159
# Epoch  600: Mean Training Loss = 0.00125
# Epoch  700: Mean Training Loss = 0.00115
# Epoch  800: Mean Training Loss = 0.00119
# Epoch  900: Mean Training Loss = 0.00095
# Epoch 1000: Mean Training Loss = 0.00079
# Epoch 1100: Mean Training Loss = 0.00081
# Epoch 1200: Mean Training Loss = 0.00098
# Epoch 1300: Mean Training Loss = 0.00072
# Epoch 1400: Mean Training Loss = 0.00075
# Epoch 1500: Mean Training Loss = 0.00062
# Epoch 1600: Mean Training Loss = 0.00055
# Epoch 1700: Mean Training Loss = 0.00059
# Epoch 1800: Mean Training Loss = 0.00054
# Epoch 1900: Mean Training Loss = 0.00050

# %%
# Test the Model:

model.eval()
test_loss = 0
with torch.no_grad():
    for batch_X_news, batch_X_price, batch_y in test_loader:
        batch_X_news, batch_X_price, batch_y = batch_X_news.to(device), batch_X_price.to(device), batch_y.to(device)
        batch_y_hat = model(batch_X_price, batch_X_news)
        test_loss += criterion(batch_y_hat, batch_y).item()
        mean_test_loss = test_loss / len(test_loader)
        
print(f'Mean Test Loss = {mean_test_loss:.5f}')
# Out:
# Mean Test Loss = 0.00078

# %% [markdown]
# # Practical Application / Prediction

# %%
# Predict the next log return using the last sequence

# Take the LAST sequence_length weeks that we actually have data for
price_seq = df.drop('target', axis=1).values[-sequence_length:]      # shape (4, 19)
news_seq  = news_embeddings.cpu().numpy()[-sequence_length:]        # shape (4, 768)

# Add batch dimension
price_tensor = torch.tensor(price_seq, dtype=torch.float32).unsqueeze(0).to(device)  # (1,4,19)
news_tensor  = torch.tensor(news_seq,  dtype=torch.float32).unsqueeze(0).to(device)  # (1,4,768)

model.eval()
with torch.no_grad():
    pred_log_return = model(price_tensor, news_tensor).cpu().item()

# Last actual closing price
last_close_scaled = df[['Close']].iloc[-1:].values
last_close = scaler.inverse_transform(
    np.hstack([last_close_scaled, np.zeros((1, len(price_cols)-1))])
)[0, 0]

predicted_close = last_close * np.exp(pred_log_return)

print(f"Last observed date   : {df.index[-1].strftime('%Y-%m-%d')}  →  Close = ${last_close:.2f}")
print(f"Predicting           : {(df.index[-1] + timedelta(days=7)).strftime('%Y-%m-%d')}")
print(f"Predicted log return : {pred_log_return:+.5f}")
print(f"Predicted close      : ${predicted_close:.2f}({(predicted_close/last_close-1):.2%})")
# Out:
# Last observed date   : 2025-11-28  →  Close = $683.39
# Predicting           : 2025-12-05
# Predicted log return : +0.00358
# Predicted close      : $685.84(0.36%)

# %%
# Monte Carlo simulation

prediction_std = np.sqrt(mean_test_loss)  # Using this as std dev (MTE is an approximation of variance)
n_simulations = 10_000

# Simulate log returns
sim_log_returns = np.random.normal(pred_log_return, prediction_std, n_simulations)

# Compute simulated prices
sim_prices = last_close * np.exp(sim_log_returns)

# Percentiles for nice reporting
p10, p50, p90 = np.percentile(sim_prices, [10, 50, 90])

print(f"\nPredicted SPY close on {(df.index[-1] + timedelta(days=7)).strftime('%Y-%m-%d')}:")
print(f"  Point estimate      : ${predicted_close:6.2f}({(predicted_close/last_close-1):.2%})")
print(f"  80% prediction interval : ${p10:6.2f}({(p10/last_close-1):.2%}) - ${p90:6.2f}({(p90/last_close-1):.2%})")
print(f"  Median of simulations   : ${p50:6.2f}({(p50/last_close-1):.2%})")

# Plot
plt.figure(figsize=(10,6))
plt.hist(sim_prices, bins=80, density=True, alpha=0.8, color="#9caff5", edgecolor='white')
plt.axvline(predicted_close, color='red', linewidth=2, label='Point prediction')
plt.axvline(p10, color='orange', linestyle='--', label='10th percentile')
plt.axvline(p90, color='orange', linestyle='--', label='90th percentile')
plt.axvline(last_close, color='green', linewidth=3, label = 'Last Close')
plt.title(f'Monte Carlo Distribution of SPY Closing Price - {(df.index[-1] + timedelta(days=7)).strftime("%Y-%m-%d")}\n(10,000 simulations, uncertainty = test RMSE)')
plt.xlabel('SPY Closing Price ($)')
plt.ylabel('Density')
plt.legend()
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()
# Out:
# Predicted SPY close on 2025-12-05:
#   Point estimate      : $685.84(0.36%)
#   80% prediction interval : $661.39(-3.22%) - $710.57(3.98%)
#   Median of simulations   : $685.76(0.35%)

# %%
# Compare Model Prediction to Actual Close on 2025-12-05
print(f'Actual Close of SPY on {(df.index[-1] + timedelta(days=7)).strftime("%Y-%m-%d")} was ${test_close:.2f} (a difference of ${(test_close-predicted_close):.2f})')
# Out:
# Actual Close of SPY on 2025-12-05 was $685.69 (a difference of $-0.15)
